# %% [markdown]
# <a href="https://colab.research.google.com/github/batuhanyndny/intro/blob/master/DL_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Short Intro to  Deep Learning
#
# **-Methods and Basics of neural networks**
#
#
# **-Simple Neural Network Example**

# %% [markdown]
# # Methods
#  * ***Regression***
#
# *  ***Classification***

# %% [markdown]
# # ** Linear Regression**

# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
data=pd.read_csv("https://raw.githubusercontent.com/batuhanyndny/intro/master/2-TypesOfML/ipynb/data/Advertising.csv")

# %%
sns.pairplot(data,x_vars=["TV"],y_vars="Sales",size=8,aspect=1.4,kind="reg")

# %% [markdown]
# # **Classification**

# %%
from sklearn.datasets import load_iris
iris= load_iris()

# %%
print(iris.data)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
#  [4.6 3.2 1.4 0.2]
#  [5.3 3.7 1.5 0.2]
#  [5.  3.3 1.4 0.2]
#  [7.  3.2 4.7 1.4]
#  [6.4 3.2 4.5 1.5]
#  [6.9 3.1 4.9 1.5]
#  [5.5 2.3 4.  1.3]
#  [6.5 2.8 4.6 1.5]
#  [5.7 2.8 4.5 1.3]
#  [6.3 3.3 4.7 1.6]
#  [4.9 2.4 3.3 1. ]
#  [6.6 2.9 4.6 1.3]
#  [5.2 2.7 3.9 1.4]
#  [5.  2.  3.5 1. ]
#  [5.9 3.  4.2 1.5]
#  [6.  2.2 4.  1. ]
#  [6.1 2.9 4.7 1.4]
#  [5.6 2.9 3.6 1.3]
#  [6.7 3.1 4.4 1.4]
#  [5.6 3.  4.5 1.5]
#  [5.8 2.7 4.1 1. ]
#  [6.2 2.2 4.5 1.5]
#  [5.6 2.5 3.9 1.1]
#  [5.9 3.2 4.8 1.8]
#  [6.1 2.8 4.  1.3]
#  [6.3 2.5 4.9 1.5]
#  [6.1 2.8 4.7 1.2]
#  [6.4 2.9 4.3 1.3]
#  [6.6 3.  4.4 1.4]
#  [6.8 2.8 4.8 1.4]
#  [6.7 3.  5.  1.7]
#  [6.  2.9 4.5 1.5]
#  [5.7 2.6 3.5 1. ]
#  [5.5 2.4 3.8 1.1]
#  [5.5 2.4 3.7 1. ]
#  [5.8 2.7 3.9 1.2]
#  [6.  2.7 5.1 1.6]
#  [5.4 3.  4.5 1.5]
#  [6.  3.4 4.5 1.6]
#  [6.7 3.1 4.7 1.5]
#  [6.3 2.3 4.4 1.3]
#  [5.6 3.  4.1 1.3]
#  [5.5 2.5 4.  1.3]
#  [5.5 2.6 4.4 1.2]
#  [6.1 3.  4.6 1.4]
#  [5.8 2.6 4.  1.2]
#  [5.  2.3 3.3 1. ]
#  [5.6 2.7 4.2 1.3]
#  [5.7 3.  4.2 1.2]
#  [5.7 2.9 4.2 1.3]
#  [6.2 2.9 4.3 1.3]
#  [5.1 2.5 3.  1.1]
#  [5.7 2.8 4.1 1.3]
#  [6.3 3.3 6.  2.5]
#  [5.8 2.7 5.1 1.9]
#  [7.1 3.  5.9 2.1]
#  [6.3 2.9 5.6 1.8]
#  [6.5 3.  5.8 2.2]
#  [7.6 3.  6.6 2.1]
#  [4.9 2.5 4.5 1.7]
#  [7.3 2.9 6.3 1.8]
#  [6.7 2.5 5.8 1.8]
#  [7.2 3.6 6.1 2.5]
#  [6.5 3.2 5.1 2. ]
#  [6.4 2.7 5.3 1.9]
#  [6.8 3.  5.5 2.1]
#  [5.7 2.5 5.  2. ]
#  [5.8 2.8 5.1 2.4]
#  [6.4 3.2 5.3 2.3]
#  [6.5 3.  5.5 1.8]
#  [7.7 3.8 6.7 2.2]
#  [7.7 2.6 6.9 2.3]
#  [6.  2.2 5.  1.5]
#  [6.9 3.2 5.7 2.3]
#  [5.6 2.8 4.9 2. ]
#  [7.7 2.8 6.7 2. ]
#  [6.3 2.7 4.9 1.8]
#  [6.7 3.3 5.7 2.1]
#  [7.2 3.2 6.  1.8]
#  [6.2 2.8 4.8 1.8]
#  [6.1 3.  4.9 1.8]
#  [6.4 2.8 5.6 2.1]
#  [7.2 3.  5.8 1.6]
#  [7.4 2.8 6.1 1.9]
#  [7.9 3.8 6.4 2. ]
#  [6.4 2.8 5.6 2.2]
#  [6.3 2.8 5.1 1.5]
#  [6.1 2.6 5.6 1.4]
#  [7.7 3.  6.1 2.3]
#  [6.3 3.4 5.6 2.4]
#  [6.4 3.1 5.5 1.8]
#  [6.  3.  4.8 1.8]
#  [6.9 3.1 5.4 2.1]
#  [6.7 3.1 5.6 2.4]
#  [6.9 3.1 5.1 2.3]
#  [5.8 2.7 5.1 1.9]
#  [6.8 3.2 5.9 2.3]
#  [6.7 3.3 5.7 2.5]
#  [6.7 3.  5.2 2.3]
#  [6.3 2.5 5.  1.9]
#  [6.5 3.  5.2 2. ]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.  5.1 1.8]]

# %% [markdown]
# ![***Iris***](https://github.com/batuhanyndny/intro/blob/master/DL/iris_petal_sepal.png?raw=true)

# %%
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
from sklearn.neighbors import KNeighborsClassifier
X = iris.data
y = iris.target
knn = KNeighborsClassifier(n_neighbors=1)
print(knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform')

# %%
knn.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform')

# %%
knn.predict([[2,4,3,2]])
# Out:
# array([1])

# %% [markdown]
# # ***Basic Neural Network Example***

# %%
# !pip3 install http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl torchvision
# Out:
# Requirement already satisfied: torch==0.4.1 from http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl in /usr/local/lib/python3.6/dist-packages (0.4.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.11.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (5.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.14.6)

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
from torch.utils.data.sampler import SubsetRandomSampler

# %%
# !nvidia-smi
# Out:
# Tue Dec 18 13:12:24 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 396.44                 Driver Version: 396.44                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    70W / 149W |    293MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16,
                                          shuffle=True, num_workers=2)

devtestset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
batch_size = 16
test_split = .3
shuffle_dataset = True
random_seed= 42

# Creating data indices for training and validation splits:
tevtestset_size = len(devtestset)
indices = list(range(tevtestset_size))
split = int(np.floor(test_split * tevtestset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
dev_indices, test_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
dev_sampler = SubsetRandomSampler(dev_indices)
test_sampler = SubsetRandomSampler(test_indices)

devloader = torch.utils.data.DataLoader(devtestset, batch_size=batch_size, 
                                           sampler=dev_sampler)
testloader = torch.utils.data.DataLoader(devtestset, batch_size=batch_size,
                                                sampler=test_sampler)

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(16)))
# Out:
#  deer truck   car   car  frog horse  bird truck  bird  deer horse   dog   dog   car  bird   car
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fb666e1da20>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer

# %% [markdown]
# # ***Define a CNN***

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 3) # channels filters 5x5 filter
        self.pool = nn.MaxPool2d(2, 2)  # 2x2 grid 
        self.conv2 = nn.Conv2d(6, 16, 3) # filters 6 filters at top , 16 filters , grid 5 
        self.conv3= nn.Conv2d(16,18,3)
        self.dropout1 = nn.Dropout(0.01)
        self.fc1 = nn.Linear(18*2*2,256)
        self.fc2 = nn.Linear(256,128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64,32)
        self.fc5 = nn.Linear(32,16)
        self.fc6 = nn.Linear(16,10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1,72)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.dropout1(x)
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x=self.fc6(x)
        return x

net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(16, 18, kernel_size=(3, 3), stride=(1, 1))
#   (dropout1): Dropout(p=0.01)
#   (fc1): Linear(in_features=72, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=64, bias=True)
#   (fc4): Linear(in_features=64, out_features=32, bias=True)
#   (fc5): Linear(in_features=32, out_features=16, bias=True)
#   (fc6): Linear(in_features=16, out_features=10, bias=True)
# )

# %% [markdown]
# # ***Define a Optimizer and Loss Function***

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# # ***Train the Network***

# %%
num_epochs = 50

# Used for tracking loss and plotting later
train_losses2 = []
dev_losses2 = []

print('Training...')
for epoch in range(num_epochs):  # loop over the dataset multiple times
    print('Epoch', epoch)
    train_loss = 0.0   
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data
      
        # Send the inputs to GPU if available
        inputs, labels = inputs.to(device), labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # track loss for printing
        train_loss += loss.item()
       
    # print average dev loss
    avg_train_loss = train_loss/len(trainloader)
    print('  average train mini-batch loss: {:.6f}'.format(avg_train_loss))
    train_losses2.append(avg_train_loss)

    # Calculate dev loss after every epoch
    with torch.no_grad():
        dev_loss = 0.0
        for data in devloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            loss = criterion(outputs, labels)
            dev_loss += loss.item()
        avg_dev_loss = dev_loss/len(devloader)
        print('  average dev mini-batch loss: {:.6f}'.format(avg_dev_loss))
        dev_losses2.append(avg_dev_loss)
            
    # Save the model so we can restore later
    print('  saving model checkpoint')
    # See https://pytorch.org/tutorials/beginner/saving_loading_models.html
    torch.save(net.state_dict(), 'net_checkpoint_{}.pth'.format(epoch))

print('Finished Training')
# Out:
# Training...
# Epoch 0
#   average train mini-batch loss: 2.303899
#   average dev mini-batch loss: 2.302591
#   saving model checkpoint
# Epoch 1
#   average train mini-batch loss: 2.302807
#   average dev mini-batch loss: 2.302839
#   saving model checkpoint
# Epoch 2
#   average train mini-batch loss: 2.302783
#   average dev mini-batch loss: 2.302561
#   saving model checkpoint
# Epoch 3
#   average train mini-batch loss: 2.302781
#   average dev mini-batch loss: 2.302724
#   saving model checkpoint
# Epoch 4
#   average train mini-batch loss: 2.302706
#   average dev mini-batch loss: 2.302468
#   saving model checkpoint
# Epoch 5
#   average train mini-batch loss: 2.302652
#   average dev mini-batch loss: 2.302266
#   saving model checkpoint
# Epoch 6
#   average train mini-batch loss: 2.302470
#   average dev mini-batch loss: 2.302266
#   saving model checkpoint
# Epoch 7
#   average train mini-batch loss: 2.301940
#   average dev mini-batch loss: 2.301077
#   saving model checkpoint
# Epoch 8
#   average train mini-batch loss: 2.292127
#   average dev mini-batch loss: 2.237332
#   saving model checkpoint
# Epoch 9
#   average train mini-batch loss: 2.044802
#   average dev mini-batch loss: 1.909104
#   saving model checkpoint
# Epoch 10
#   average train mini-batch loss: 1.893141
#   average dev mini-batch loss: 1.842954
#   saving model checkpoint
# Epoch 11
#   average train mini-batch loss: 1.819986
#   average dev mini-batch loss: 1.760417
#   saving model checkpoint
# Epoch 12
#   average train mini-batch loss: 1.691765
#   average dev mini-batch loss: 1.614523
#   saving model checkpoint
# Epoch 13
#   average train mini-batch loss: 1.570153
#   average dev mini-batch loss: 1.505306
#   saving model checkpoint
# Epoch 14
#   average train mini-batch loss: 1.497908
#   average dev mini-batch loss: 1.463018
#   saving model checkpoint
# Epoch 15
#   average train mini-batch loss: 1.447346
#   average dev mini-batch loss: 1.398040
#   saving model checkpoint
# Epoch 16
#   average train mini-batch loss: 1.403197
#   average dev mini-batch loss: 1.416909
#   saving model checkpoint
# Epoch 17
#   average train mini-batch loss: 1.357430
#   average dev mini-batch loss: 1.395619
#   saving model checkpoint
# Epoch 18
#   average train mini-batch loss: 1.317082
#   average dev mini-batch loss: 1.341265
#   saving model checkpoint
# Epoch 19
#   average train mini-batch loss: 1.268676
#   average dev mini-batch loss: 1.265505
#   saving model checkpoint
# Epoch 20
#   average train mini-batch loss: 1.214016
#   average dev mini-batch loss: 1.225321
#   saving model checkpoint
# Epoch 21
#   average train mini-batch loss: 1.177791
#   average dev mini-batch loss: 1.190436
#   saving model checkpoint
# Epoch 22
#   average train mini-batch loss: 1.141775
#   average dev mini-batch loss: 1.202551
#   saving model checkpoint
# Epoch 23
#   average train mini-batch loss: 1.114062
#   average dev mini-batch loss: 1.180020
#   saving model checkpoint
# Epoch 24
#   average train mini-batch loss: 1.088712
#   average dev mini-batch loss: 1.188332
#   saving model checkpoint
# Epoch 25
#   average train mini-batch loss: 1.061633
#   average dev mini-batch loss: 1.129932
#   saving model checkpoint
# Epoch 26
#   average train mini-batch loss: 1.038235
#   average dev mini-batch loss: 1.142117
#   saving model checkpoint
# Epoch 27
#   average train mini-batch loss: 1.014910
#   average dev mini-batch loss: 1.105499
#   saving model checkpoint
# Epoch 28
#   average train mini-batch loss: 0.994453
#   average dev mini-batch loss: 1.106920
#   saving model checkpoint
# Epoch 29
#   average train mini-batch loss: 0.971738
#   average dev mini-batch loss: 1.097673
#   saving model checkpoint
# Epoch 30
#   average train mini-batch loss: 0.954618
#   average dev mini-batch loss: 1.094556
#   saving model checkpoint
# Epoch 31
#   average train mini-batch loss: 0.938307
#   average dev mini-batch loss: 1.089956
#   saving model checkpoint
# Epoch 32
#   average train mini-batch loss: 0.920004
#   average dev mini-batch loss: 1.118977
#   saving model checkpoint
# Epoch 33
#   average train mini-batch loss: 0.903212
#   average dev mini-batch loss: 1.111771
#   saving model checkpoint
# Epoch 34
#   average train mini-batch loss: 0.887164
#   average dev mini-batch loss: 1.108853
#   saving model checkpoint
# Epoch 35
#   average train mini-batch loss: 0.872578
#   average dev mini-batch loss: 1.092598
#   saving model checkpoint
# Epoch 36
#   average train mini-batch loss: 0.853599
#   average dev mini-batch loss: 1.113540
#   saving model checkpoint
# Epoch 37
#   average train mini-batch loss: 0.840910
#   average dev mini-batch loss: 1.135449
#   saving model checkpoint
# Epoch 38
#   average train mini-batch loss: 0.826875
#   average dev mini-batch loss: 1.132239
#   saving model checkpoint
# Epoch 39
#   average train mini-batch loss: 0.807764
#   average dev mini-batch loss: 1.145669
#   saving model checkpoint
# Epoch 40
#   average train mini-batch loss: 0.797209
#   average dev mini-batch loss: 1.151113
#   saving model checkpoint
# Epoch 41
#   average train mini-batch loss: 0.781059
#   average dev mini-batch loss: 1.173172
#   saving model checkpoint
# Epoch 42
#   average train mini-batch loss: 0.768952
#   average dev mini-batch loss: 1.237684
#   saving model checkpoint
# Epoch 43
#   average train mini-batch loss: 0.751085
#   average dev mini-batch loss: 1.190349
#   saving model checkpoint
# Epoch 44
#   average train mini-batch loss: 0.740409
#   average dev mini-batch loss: 1.211501
#   saving model checkpoint
# Epoch 45
#   average train mini-batch loss: 0.729020
#   average dev mini-batch loss: 1.193928
#   saving model checkpoint
# Epoch 46
#   average train mini-batch loss: 0.712995
#   average dev mini-batch loss: 1.199812
#   saving model checkpoint
# Epoch 47
#   average train mini-batch loss: 0.700438
#   average dev mini-batch loss: 1.242500
#   saving model checkpoint
# Epoch 48
#   average train mini-batch loss: 0.684642
#   average dev mini-batch loss: 1.251407
#   saving model checkpoint
# Epoch 49
#   average train mini-batch loss: 0.672963
#   average dev mini-batch loss: 1.275775
#   saving model checkpoint
# Finished Training

# %%
import matplotlib.pyplot as plt
plt.plot(train_losses2, label='Train loss')
plt.plot(dev_losses2, label='Dev loss')
plt.legend()
plt.show()

# %%
#Load the best epoch for best results
best_net = Net()
best_epoch = np.argmin(dev_losses2)
best_net.load_state_dict(torch.load('net_checkpoint_{}.pth'.format(best_epoch)))
best_net.eval()
best_net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(16, 18, kernel_size=(3, 3), stride=(1, 1))
#   (dropout1): Dropout(p=0.01)
#   (fc1): Linear(in_features=72, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=64, bias=True)
#   (fc4): Linear(in_features=64, out_features=32, bias=True)
#   (fc5): Linear(in_features=32, out_features=16, bias=True)
#   (fc6): Linear(in_features=16, out_features=10, bias=True)
# )

# %%
# Calculate dev loss after every epoch
with torch.no_grad():
    test_loss = 0.0
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = best_net(images)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
    avg_test_loss = test_loss/len(testloader)
    print('  average test mini-batch loss: {:.6f}'.format(avg_test_loss))
# Out:
#   average test mini-batch loss: 1.121634

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(train_losses2, label='Train loss')
plt.plot(dev_losses2, label='Dev loss')
plt.scatter(best_epoch, avg_test_loss, marker='x', color='r', label='Test loss at best_epoch')
plt.legend()
plt.show()

# %% [markdown]
# ***Early Stopping:***
#
# ![Early Stopping](https://github.com/batuhanyndny/intro/blob/master/DL/early_stopping.png?raw=1)

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 61 %

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 77 %
# Accuracy of   car : 68 %
# Accuracy of  bird : 53 %
# Accuracy of   cat : 41 %
# Accuracy of  deer : 59 %
# Accuracy of   dog : 52 %
# Accuracy of  frog : 74 %
# Accuracy of horse : 69 %
# Accuracy of  ship : 73 %
# Accuracy of truck : 60 %
